# %%
# %matplotlib widget

# %%
from astromusic.players.multi import UI
UI()
# Out:
# UI(children=(Checkbox(value=False, description='All'), SingleToneUI(children=(Checkbox(value=False, descriptio…

# %%
from astromusic.players.multi import MergedWaveUI
MergedWaveUI()
# Out:
# MergedWaveUI(children=(Checkbox(value=False, description='All'), SingleToneUI(children=(Checkbox(value=False, …
