# %%
# %matplotlib notebook

# %%
from astromusic.players.constampl import ConstAmplPlayer
app = ConstAmplPlayer.UI()
app.show()
# Out:
# ...
# IntSlider(value=12, layout=Layout(width='100%'), max=36)
# ...
# <img src="data:image/png;base64,..." width="639.9999861283738">
