# %%
# %matplotlib widget

# %% [markdown]
# # deprecated code
#
# Old player experiences discontinuities between blocks when frequency changes rapidly, which is resolved in the VaryFreqWave class (see below)
#
#  ```python
# from astromusic.players.constampl import ConstAmplPlayer
# app = ConstAmplPlayer.UI()
# app.show()
# ```

# %%
from astromusic.players.constampl import UI
UI()
# Out:
# UI(children=(HBox(children=(Button(icon='play', style=ButtonStyle()), Label(value='440 Hz'))), IntSlider(value…
